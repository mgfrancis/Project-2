# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import pymongo
import re
import json

# Google API Key
from config import gkey

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"


# San Juan 18.466333,-66.105721
# Ponce 18.01108, -66.61406
# Rincon 18.340216, -67.250015
# Fajardo 18.325787, -65.652382
# Arecibo 18.47245, -66.71573

# spanish, puertorican, middle eastern, chinese, fast food, bar restaurant
params = {
    "location": "18.466333,-66.105721",  # San Juan coords
    "rankby": "distance",
    "types": "restaurant",
    "key": gkey
    #"types": "address",
    #"keyword": ["spanish", "puertorican", "middle eastern", "chinese", "fast food", "bar restaurant"]
}



response = requests.get(base_url, params=params).json()
response

results = response['results']
results
# Out:
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 18.4655394, 'lng': -66.1057355},
#    'viewport': {'northeast': {'lat': 18.4668890302915,
#      'lng': -66.1044064697085},
#     'southwest': {'lat': 18.46419106970849, 'lng': -66.1071044302915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': "Bebo's BBQ",
#   'place_id': 'ChIJW-012VRvA4wRhxrQSQZH-6I',
#   'plus_code': {'compound_code': 'FV8V+6P San Juan, Puerto Rico',
#    'global_code': '77CMFV8V+6P'},
#   'reference': 'ChIJW-012VRvA4wRhxrQSQZH-6I',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': 'San Juan'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 18.4655394, 'lng': -66.1057355},
#    'viewport': {'northeast': {'lat': 18.4668890302915,
#      'lng': -66.1044064697085},
#     'southwest': {'lat': 18.46419106970849, 'lng': -66.1071044302915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Quedely San Juan',
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110804819799981264142">Sussan de Leon</a>'],
#     'photo_reference': 'ATtYBwLgV0TvOQKqrEpVoK9Zm63ASPkFxGO71pS22p0IKD3n_yInOorpkqtgHft6ltKeKj8dANqlF5GOAmjAc69e0KNL1DQsYQBTBIwGFW1E0f82Idmo-eVGBP-JYMcBc5ZlBWX2JLoeFlbTEIfhtnjqAK6x4-F6-_feS1sDn8cnmby4JPa9',
#     'width': 4032}],
#   'place_id': 'ChIJ_92VstxuA4wR5SO3o199KrU',
#   'plus_code': {'compound_code': 'FV8V+6P San Juan, Puerto Rico',
#    'global_code': '77CMFV8V+6P'},
#   'reference': 'ChIJ_92VstxuA4wR5SO3o199KrU',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': 'San Juan'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 18.4654898, 'lng': -66.1057113},
#    'viewport': {'northeast': {'lat': 18.4668397802915,
#      'lng': -66.10440676970849},
#     'southwest': {'lat': 18.4641418197085, 'lng': -66.1071047302915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Cheos BBQ',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 828,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108767761550952085489">carlos quinones</a>'],
#     'photo_reference': 'ATtYBwISuNILWIfqDF4H0csc7hKAs_rQeMqyhvePyENVY8YjeM_bYzuH0oq36DUJKcl86G-b7YKB8Q3ssFFh_msJXUvt-1-ZYlcPr6uHvd0sEpyDhCdV9jZxAB9YuNDRA80B14hKbskRK_KZCUES2SSzcNiomkTmrizvq8ZHLfT9x5xVD6v3',
#     'width': 1048}],
#   'place_id': 'ChIJb8Eld9JvA4wRyErNRsFjqf4',
#   'plus_code': {'compound_code': 'FV8V+5P San Juan, Puerto Rico',
#    'global_code': '77CMFV8V+5P'},
#   'reference': 'ChIJb8Eld9JvA4wRyErNRsFjqf4',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': 'San Juan'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 18.4655727, 'lng': -66.1061596},
#    'viewport': {'northeast': {'lat': 18.4669249302915,
#      'lng': -66.1046893697085},
#     'southwest': {'lat': 18.4642269697085, 'lng': -66.1073873302915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#   'name': 'Bahía Tropical Bar & Restaurant',
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110863900820910752706">Ivan Reyes</a>'],
#     'photo_reference': 'ATtYBwIxrcxKStK3JIiK-QduIk-umSDpOp4_laxmkM84xoo6MgzGwKONe2-Xihn-VKF5efYltew3BdombOP8oBs7zjBWAA8mPf_0BBNwFwmhkEXUuwh5WPOqiJKKtfBLZOvwbqiK9aROejiA38ONEm9AMOi6jFtKsnXV8cwPA1zbQD2s5GnJ',
#     'width': 4032}],
#   'place_id': 'ChIJS4qFTcNuA4wRDTRJ1eogtXo',
#   'plus_code': {'compound_code': 'FV8V+6G San Juan, Puerto Rico',
#    'global_code': '77CMFV8V+6G'},
#   'rating': 4.8,
#   'reference': 'ChIJS4qFTcNuA4wRDTRJ1eogtXo',
#   'scope': 'GOOGLE',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 17,
#   'vicinity': 'Edificio Freire # 54 Local 102 Paseo Covadonga, San Juan'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 18.4654045, 'lng': -66.1061172},
#    'viewport': {'northeast': {'lat': 18.4666607302915,
#      'lng': -66.1046965197085},
#     'southwest': {'lat': 18.46396276970849, 'lng': -66.1073944802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'La Vaca Enfurecida Bikers Bar & Grill',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108098014761881242536">Alex</a>'],
#     'photo_reference': 'ATtYBwJMFyXMszO6_xZ35aWCls4vhyirjQsFapjzxpy4kLHeo15hC-NjOYWs9gkH7lVFETFfV5R2d0MAvAE8ECan45ife09jdXHDw8xRogaYdvPNbSUmiMzChZ4Mwzj7RPt8W8PD7cADNoyKJWm7qKWf0P7hf5D6STbtDpe4yQkGpzGfwOqG',
#     'width': 4032}],
#   'place_id': 'ChIJxz9AlJVvA4wR5jXJmvfBNps',
#   'plus_code': {'compound_code': 'FV8V+5H San Juan, Puerto Rico',
#    'global_code': '77CMFV8V+5H'},
#   'rating': 4.6,
#   'reference': 'ChIJxz9AlJVvA4wR5jXJmvfBNps',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 42,
#   'vicinity': 'Calle Del Tren, San Juan'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 18.465289, 'lng': -66.1072033},
#    'viewport': {'northeast': {'lat': 18.4666148302915,
#      'lng': -66.10585301970849},
#     'southwest': {'lat': 18.4639168697085, 'lng': -66.1085509802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Provençal cafe',
#   'place_id': 'ChIJVUSU6xdvA4wRIuN9ubJTysI',
#   'plus_code': {'compound_code': 'FV8V+44 San Juan, Puerto Rico',
#    'global_code': '77CMFV8V+44'},
#   'reference': 'ChIJVUSU6xdvA4wRIuN9ubJTysI',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': 'Puerto Rico 1, San Juan'},
#  {'business_status': 'CLOSED_TEMPORARILY',
#   'geometry': {'location': {'lat': 18.4646866, 'lng': -66.1065691},
#    'viewport': {'northeast': {'lat': 18.4660041302915,
#      'lng': -66.1051693197085},
#     'southwest': {'lat': 18.4633061697085, 'lng': -66.1078672802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Coci Arte Bistro & Bar',
#   'permanently_closed': True,
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110262016393577390763">Vilma Rosario</a>'],
#     'photo_reference': 'ATtYBwICQYuVGjF3VrmzfkMkcDW4LAwag4UVkf8T5fP3e8f2M9nAk_rW-gWhf_7xReGUddaS-n7k8jKrO5dCn3lCeNGVtRLgFC8BjzdXdwPcVE0N3lKvB3Rb8R3nEs96BgUYu17d5gQvd17HV32pZwjbim1frG6kGmDukfXK09v_8hFo9hbD',
#     'width': 4032}],
#   'place_id': 'ChIJBRKQqMRuA4wRfBdrWmoBE6E',
#   'plus_code': {'compound_code': 'FV7V+V9 San Juan, Puerto Rico',
#    'global_code': '77CMFV7V+V9'},
#   'rating': 5,
#   'reference': 'ChIJBRKQqMRuA4wRfBdrWmoBE6E',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 23,
#   'vicinity': '100 Calle Marina, San Juan'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 18.4647527, 'lng': -66.1067321},
#    'viewport': {'northeast': {'lat': 18.4660592302915,
#      'lng': -66.1052349197085},
#     'southwest': {'lat': 18.4633612697085, 'lng': -66.10793288029151}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Waffle-era Tea Room',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2268,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110871291860655772348">R P</a>'],
#     'photo_reference': 'ATtYBwKlfMzwIl9NUqUw18pWO__ITR_eJCt1wtftH8qcLXjY_8yHZurzFM1MdsQInbGBVq9xUOz9Mp-WOeF8BEhCMJfX5nJ_z6XUg5rkkScSXEuiw3Ayqu5eHqjldtZsiECU4giYmjnqNW9NZi_SLulBhk8B5mnwt8J9djx7T8jJdYRRGrBN',
#     'width': 4032}],
#   'place_id': 'ChIJ3zkyfMduA4wR89maYJos-QE',
#   'plus_code': {'compound_code': 'FV7V+W8 San Juan, Puerto Rico',
#    'global_code': '77CMFV7V+W8'},
#   'price_level': 2,
#   'rating': 4.5,
#   'reference': 'ChIJ3zkyfMduA4wR89maYJos-QE',
#   'scope': 'GOOGLE',
#   'types': ['cafe',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 398,
#   'vicinity': '100 Calle Marina, San Juan'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 18.4644444, 'lng': -66.10677319999999},
#    'viewport': {'northeast': {'lat': 18.4657543802915,
#      'lng': -66.10535821970849},
#     'southwest': {'lat': 18.4630564197085, 'lng': -66.1080561802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'La Burguett',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116800257986728005077">MJ Diaz</a>'],
#     'photo_reference': 'ATtYBwLNpRLYfuo6kMSVV3v-phwC6I_kKtbTrfEEdLT7yOFNmFaxwA-j53IBCRtwELXinXFct_P-PlXGF4I6CBIrCDXcBb5280zBFE0-twoOt_A2lOevlBJaWkcd73JtM62ogSZYb5hUp5YFec2ZveCxTqJR5ravABaF_fN1WD_XRY3nA3pJ',
#     'width': 4032}],
#   'place_id': 'ChIJq33fpMRuA4wRLTfzRUMvq6o',
#   'plus_code': {'compound_code': 'FV7V+Q7 San Juan, Puerto Rico',
#    'global_code': '77CMFV7V+Q7'},
#   'price_level': 2,
#   'rating': 4.6,
#   'reference': 'ChIJq33fpMRuA4wRLTfzRUMvq6o',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 537,
#   'vicinity': 'Capitolio Plaza #503, Calle Marina, San Juan'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 18.4644444, 'lng': -66.1069444},
#    'viewport': {'northeast': {'lat': 18.4657179802915,
#      'lng': -66.10546771970851},
#     'southwest': {'lat': 18.46302001970849, 'lng': -66.10816568029152}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Melao Bistro',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 5312,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116370161876518330581">rocio colon</a>'],
#     'photo_reference': 'ATtYBwImlhEJod-x5-pnNBGIiJHe2aaSNidaHdNctT_TEMjai_jYRbdR_NC8sf3_sqbaXqVc2ikZXNtqnjWt4dTlCYrbe5FcvHnmJa6pWLz3eOmpQWhJOZa_Q3ZqKWUxyuHuaX1jrvSJt1kXFXvcAR7lsd-x9C2Go6fTjXZqsk3_MLQp4WDK',
#     'width': 2988}],
#   'place_id': 'ChIJHT3lytxuA4wR9SL-VW8hXFk',
#   'plus_code': {'compound_code': 'FV7V+Q6 San Juan, Puerto Rico',
#    'global_code': '77CMFV7V+Q6'},
#   'price_level': 2,
#   'rating': 4.7,
#   'reference': 'ChIJHT3lytxuA4wR9SL-VW8hXFk',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 111,
#   'vicinity': 'Cond. Capitolio Plaza, Calle Marina Ste. 201, San Juan'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 18.464273, 'lng': -66.1068307},
#    'viewport': {'northeast': {'lat': 18.4655946802915,
#      'lng': -66.1054355197085},
#     'southwest': {'lat': 18.4628967197085, 'lng': -66.10813348029151}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'La Burguett',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1908,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104380698750265190510">angel feliciano</a>'],
#     'photo_reference': 'ATtYBwJx22DN2b1feXb2tNJuAwq__cb1O470wgvFqZBkIO2JPsqoqL1PZ0bdXtDWd7vO6alS9E9MzbAVJiJx3yyBmlvcWUIxzXeYALz2H1t4YfRmWhx2Cxe19ZmHLxFYCC7aG3wX-Vd82P_SDtE7KjU36xeDdQA9rNIDBjBypIzXzkr10SBm',
#     'width': 4032}],
#   'place_id': 'ChIJ0RyNu8RuA4wRvMrybcxCc4w',
#   'plus_code': {'compound_code': 'FV7V+P7 San Juan, Puerto Rico',
#    'global_code': '77CMFV7V+P7'},
#   'rating': 4.2,
#   'reference': 'ChIJ0RyNu8RuA4wRvMrybcxCc4w',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 39,
#   'vicinity': '100 Calle Marina, San Juan'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 18.4641315, 'lng': -66.1072073},
#    'viewport': {'northeast': {'lat': 18.4654973302915,
#      'lng': -66.1061596697085},
#     'southwest': {'lat': 18.4627993697085, 'lng': -66.10885763029151}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': "Julissa's Cyber Cafe VSJ",
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3456,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110782341475556960931">Domingo Monell</a>'],
#     'photo_reference': 'ATtYBwJ7KYZOhjCOBhVKqlv4EylypO_owDGcDogkVUXHJQdcIX0ylKwhv0ozlgVCyA2_HfWiC0oGcCxqpk2CteacYLCaw3Tcv0ueFMsNt_lq0rU6dCLvj9k5rdEoFZIpm0nbe7oJQCc1lWTE2FvarejgLwLkErgwDwa8Q7MyYxDt3NNRwfb4',
#     'width': 4608}],
#   'place_id': 'ChIJT1VMW5xvA4wRFv2pEnpMP14',
#   'plus_code': {'compound_code': 'FV7V+M4 San Juan, Puerto Rico',
#    'global_code': '77CMFV7V+M4'},
#   'rating': 4.5,
#   'reference': 'ChIJT1VMW5xvA4wRFv2pEnpMP14',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 11,
#   'vicinity': '100 Calle del Muelle, San Juan'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 18.4643145, 'lng': -66.1077055},
#    'viewport': {'northeast': {'lat': 18.4656661302915,
#      'lng': -66.1064039697085},
#     'southwest': {'lat': 18.4629681697085, 'lng': -66.1091019302915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'Barista Lounge Coffee Shop',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 728,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112877007212336025576">Barista Lounge Coffee Shop</a>'],
#     'photo_reference': 'ATtYBwLEz8DEJNqKhZ3A-MlN9GZSIunii-0l-vkakpcbhGdO4PKrcoPln2Bqr_-zBcNPEcmHX8M70tPnc9bL5Uss8PYWvf7eTkmwLJfD2j5VIp52duZmBEftXO796jkmuBONM1xPE0I6MDzMi5UcCh2lXTB1J6iwhlRuJFFP_8_hj6lCtwIB',
#     'width': 946}],
#   'place_id': 'ChIJgXzYa8RvA4wRmh5-85jZyMc',
#   'plus_code': {'compound_code': 'FV7R+PW San Juan, Puerto Rico',
#    'global_code': '77CMFV7R+PW'},
#   'rating': 5,
#   'reference': 'ChIJgXzYa8RvA4wRmh5-85jZyMc',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1,
#   'vicinity': 'Condominio Capital Plaza, 100 Calle del Muelle Ste 104, San Juan'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 18.4643145, 'lng': -66.1077055},
#    'viewport': {'northeast': {'lat': 18.4656661302915,
#      'lng': -66.1064039697085},
#     'southwest': {'lat': 18.4629681697085, 'lng': -66.1091019302915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Callejeros @ Old San Juan',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 506,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116311202686044867197">Callejeros @ Old San Juan</a>'],
#     'photo_reference': 'ATtYBwI9O7J_fxV54RJFVVmYT8B_QdH6odM8GoGwJHuEZrtFpx4eZvvftPd-s6vlDRwkMDLKd2b70LVDezeD1ETjjs4SQHluUp0pNEOnmb111PnR6HDykzvF739LZGub2f_rdrCSQbLpSNV4_JKqv1lRfvlbm2UvNwq4GeUe2R-D-aNOJj9d',
#     'width': 898}],
#   'place_id': 'ChIJHVU4ealvA4wR2H0MvhNg_Pk',
#   'plus_code': {'compound_code': 'FV7R+PW San Juan, Puerto Rico',
#    'global_code': '77CMFV7R+PW'},
#   'rating': 4.7,
#   'reference': 'ChIJHVU4ealvA4wR2H0MvhNg_Pk',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 106,
#   'vicinity': 'Condominio Capitolio Plaza, 100 Calle del Muelle Ste #302, San Juan'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 18.4640281, 'lng': -66.1076247},
#    'viewport': {'northeast': {'lat': 18.4653824802915,
#      'lng': -66.1063723197085},
#     'southwest': {'lat': 18.4626845197085, 'lng': -66.1090702802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': "Penny's Wood Pizza",
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1836,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109981638600534110996">Kaleb Camacho</a>'],
#     'photo_reference': 'ATtYBwJf4OFWgAMIElsCzcCxG-mdhlDFRWLMDzOzvOKVCJP9X8AvCr7AeT59K4XVuynBvVTxVif8wH6GQB-UW-B52Sw9DLWCc8vKzkvVt_H_b5lwwMN5qco_YwvN47DKG2CbGQSHyCJ6BuE3UzUVCVo-gbvmkGqKbeyz2b44MnLKPEuEtFek',
#     'width': 3264}],
#   'place_id': 'ChIJ6YZMcStvA4wROfuv4boWddQ',
#   'plus_code': {'compound_code': 'FV7R+JX San Juan, Puerto Rico',
#    'global_code': '77CMFV7R+JX'},
#   'rating': 4.3,
#   'reference': 'ChIJ6YZMcStvA4wROfuv4boWddQ',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 60,
#   'vicinity': 'Capitolio Plaza, San Juan'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 18.4640702, 'lng': -66.1026613},
#    'viewport': {'northeast': {'lat': 18.4654144802915,
#      'lng': -66.10131541970848},
#     'southwest': {'lat': 18.4627165197085, 'lng': -66.10401338029149}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Pollo Campero',
#   'place_id': 'ChIJsS4J-_VvA4wREAVYo6g_494',
#   'plus_code': {'compound_code': 'FV7W+JW San Juan, Puerto Rico',
#    'global_code': '77CMFV7W+JW'},
#   'reference': 'ChIJsS4J-_VvA4wREAVYo6g_494',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': 'El Tren esquina, calle Valdez, San Juan'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 18.4644444, 'lng': -66.1108333},
#    'viewport': {'northeast': {'lat': 18.4657693802915,
#      'lng': -66.10960941970849},
#     'southwest': {'lat': 18.4630714197085, 'lng': -66.1123073802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': "Taster's Place",
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2988,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101553152083054790742">Nick Thompson</a>'],
#     'photo_reference': 'ATtYBwICxxvBdpGGDz1a2y43Dido5FjEcIq8xFo-Ph-4tRNrKoBrdRv1rCSBqF_EDLKDSqDfn6A5oGilzeY9VFr9-Orw7xo2m7qTZB0enZn1JYNbldMudtsC2ZYexUOzOF2khalLpTo3U0jgu7aOBqhXaiWhQ8kz2r3bDlmeAGxoQ2njx3Qp',
#     'width': 3984}],
#   'place_id': 'ChIJqSJZPVVvA4wRbvHyg9s21_o',
#   'plus_code': {'compound_code': 'FV7Q+QM San Juan, Puerto Rico',
#    'global_code': '77CMFV7Q+QM'},
#   'rating': 4.5,
#   'reference': 'ChIJqSJZPVVvA4wRbvHyg9s21_o',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 17,
#   'vicinity': 'San Juan'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 18.4643031, 'lng': -66.11086630000001},
#    'viewport': {'northeast': {'lat': 18.4656338802915,
#      'lng': -66.1096120697085},
#     'southwest': {'lat': 18.4629359197085, 'lng': -66.11231003029151}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Restaurante Mi Tierra',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 480,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106980575743804843981">jd dones</a>'],
#     'photo_reference': 'ATtYBwKg0H0R9nr8hTRfF2kSDqY9jB3YQKZsRTH66oG2GQqUsZ6iyp2fp08rrWtsnAhCQAXQWbGTO4PdCVbaJyOFdzH-BM4_HbC33y4OtYgKX1-32MaQLjsPmaEK8raKUXlSDUQsVXQiMDbAi5atGRA8NFWaWCVCY60MEsfU2XuUME-eqEcm',
#     'width': 720}],
#   'place_id': 'ChIJMfjcLnlvA4wRTOszHzLYWd8',
#   'plus_code': {'compound_code': 'FV7Q+PM San Juan, Puerto Rico',
#    'global_code': '77CMFV7Q+PM'},
#   'rating': 4.4,
#   'reference': 'ChIJMfjcLnlvA4wRTOszHzLYWd8',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 72,
#   'vicinity': 'Calle Corretjer, Paseo Covadonga #104, San Juan'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 18.4644197, 'lng': -66.1110415},
#    'viewport': {'northeast': {'lat': 18.4657662302915,
#      'lng': -66.10970506970848},
#     'southwest': {'lat': 18.4630682697085, 'lng': -66.1124030302915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Frappe Maker',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 4128,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107231383551518506605">Jay Torres</a>'],
#     'photo_reference': 'ATtYBwJhIHAQIfs3qxF3zrz9y0KD97VL-Sr0Ljty1pkBG4ENTLSxJTPKMTT3Oln3Tvobg-8P6NeZrB0oUsFz4UsZ8YKE6UJ790NxIc2IOm8mx6UHniGoGN2vofvB_KBwhHsnCwctspXudfQwoH1gqNasalDMCr2m7NwpCD4x79OOMqJtpfBi',
#     'width': 2322}],
#   'place_id': 'ChIJifr9GcRuA4wRQNVYYp4_Tlo',
#   'plus_code': {'compound_code': 'FV7Q+QH San Juan, Puerto Rico',
#    'global_code': '77CMFV7Q+QH'},
#   'rating': 4.5,
#   'reference': 'ChIJifr9GcRuA4wRQNVYYp4_Tlo',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 39,
#   'vicinity': 'Calle Juan Antonio Corretjer, San Juan'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 18.4653461, 'lng': -66.09997249999999},
#    'viewport': {'northeast': {'lat': 18.4667547802915,
#      'lng': -66.0986165197085},
#     'southwest': {'lat': 18.4640568197085, 'lng': -66.1013144802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Ladis place',
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100819835919297111976">Sky Scan</a>'],
#     'photo_reference': 'ATtYBwK3cHAg_JqZEQ4SwCeTzgsViexG4r9C9DLAsVH2Y58IOIqn07oXO2zrG5Alo4bloRKbId_towXJhy80806CpyGVlpxLP41HtTHFT4CAe0ob2MKPglku4wnr9dLVPuZ-mu5Jy85ACrqjAKT817xP8g1yZDXYlhzRcdElX5XAv-4DfjYp',
#     'width': 4032}],
#   'place_id': 'ChIJ_1Py-XZvA4wRLflO9QWewiw',
#   'plus_code': {'compound_code': 'FW82+42 San Juan, Puerto Rico',
#    'global_code': '77CMFW82+42'},
#   'rating': 4.4,
#   'reference': 'ChIJ_1Py-XZvA4wRLflO9QWewiw',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 5,
#   'vicinity': '250 Avenida de la Constitución, San Juan'}]

# %%
for row in results:
    try:
        Name =  row["name"]
        #URL =  row["photos"]["html_attributions"]
        Rating =  row["rating"]
        Address =  row["vicinity"]
        Status = row["business_status"]
     
        print('------------')
        print(Name)
        print(Rating)
        print(Address)
        print(Status)
        #print(URL)
        
    except KeyError as e:
        print(e)
# Out:
# 'rating'
# 'rating'
# 'rating'
# ------------
# Bahía Tropical Bar & Restaurant
# 4.8
# Edificio Freire # 54 Local 102 Paseo Covadonga, San Juan
# OPERATIONAL
# ------------
# La Vaca Enfurecida Bikers Bar & Grill
# 4.6
# Calle Del Tren, San Juan
# OPERATIONAL
# 'rating'
# ------------
# Coci Arte Bistro & Bar
# 5
# 100 Calle Marina, San Juan
# CLOSED_TEMPORARILY
# ------------
# Waffle-era Tea Room
# 4.5
# 100 Calle Marina, San Juan
# OPERATIONAL
# ------------
# La Burguett
# 4.6
# Capitolio Plaza #503, Calle Marina, San Juan
# OPERATIONAL
# ------------
# Melao Bistro
# 4.7
# Cond. Capitolio Plaza, Calle Marina Ste. 201, San Juan
# OPERATIONAL
# ------------
# La Burguett
# 4.2
# 100 Calle Marina, San Juan
# OPERATIONAL
# ------------
# Julissa's Cyber Cafe VSJ
# 4.5
# 100 Calle del Muelle, San Juan
# OPERATIONAL
# ------------
# Barista Lounge Coffee Shop
# 5
# Condominio Capital Plaza, 100 Calle del Muelle Ste 104, San Juan
# OPERATIONAL
# ------------
# Callejeros @ Old San Juan
# 4.7
# Condominio Capitolio Plaza, 100 Calle del Muelle Ste #302, San Juan
# OPERATIONAL
# ------------
# Penny's Wood Pizza
# 4.3
# Capitolio Plaza, San Juan
# OPERATIONAL
# 'rating'
# ------------
# Taster's Place
# 4.5
# San Juan
# OPERATIONAL
# ------------
# Restaurante Mi Tierra
# 4.4
# Calle Corretjer, Paseo Covadonga #104, San Juan
# OPERATIONAL
# ------------
# Frappe Maker
# 4.5
# Calle Juan Antonio Corretjer, San Juan
# OPERATIONAL
# ------------
# Ladis place
# 4.4
# 250 Avenida de la Constitución, San Juan
# OPERATIONAL
